# %%
import json
import os
import nltk
import random
from nltk.corpus import stopwords
from nltk.corpus import opinion_lexicon
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
import pandas as pd
import pickle

# %%
filename = 'imdb_master.csv'
df = pd.read_csv(filename,encoding='latin1')

# %%
df_train = df[(df['type'] == 'train') & (df['label'] != 'unsup')]
df_test = df[(df['type'] == 'test') & (df['label'] != 'unsup')]

# %%
df_train.head()
# Out:
#        Unnamed: 0   type                                             review  \
# 25000       25000  train  Story of a man who has unnatural feelings for ...
# 25001       25001  train  Airport '77 starts as a brand new luxury 747 p...
# 25002       25002  train  This film lacked something I couldn't put my f...
# 25003       25003  train  Sorry everyone,,, I know this is supposed to b...
# 25004       25004  train  When I was little my parents took me along to ...
#
#       label         file
# 25000   neg      0_3.txt
# 25001   neg  10000_4.txt
# 25002   neg  10001_4.txt
# 25003   neg  10002_1.txt
# 25004   neg  10003_1.txt

# %%
df_test.head()
# Out:
#    Unnamed: 0  type                                             review label  \
# 0           0  test  Once again Mr. Costner has dragged out a movie...   neg
# 1           1  test  This is an example of why the majority of acti...   neg
# 2           2  test  First of all I hate those moronic rappers, who...   neg
# 3           3  test  Not even the Beatles could write songs everyon...   neg
# 4           4  test  Brass pictures (movies is not a fitting word f...   neg
#
#           file
# 0      0_2.txt
# 1  10000_4.txt
# 2  10001_1.txt
# 3  10002_3.txt
# 4  10003_3.txt

# %%
def get_reviews_and_labels(df):
    reviews = df['review'].tolist()
    labels = df['label'].tolist()
    return reviews,labels

# %%
x_train, y_train = get_reviews_and_labels(df_train)
x_test, y_test = get_reviews_and_labels(df_test)

# %%
#clean all the transcripts (stop words and stemming)
def clean(x):
    stop_words = set(stopwords.words('english'))
    ps = PorterStemmer()
    filtered_x = []

    for t in x:
         t = t.lower()
         t_tokens = word_tokenize(t)
         stopworded_t = [w for w in t_tokens if not w in stop_words]
         stemmed_t = []
         for word in stopworded_t:
            stemmed_t.append(ps.stem(word))
         filtered_x.append(stemmed_t)
    return filtered_x

# %%
cleaned_x_train = clean(x_train)
cleaned_x_test =  clean(x_test)

# %%
filtered_x = cleaned_x_train + cleaned_x_test

# collect fetures
all_words = []

for row in filtered_x:
    for w in row:
        all_words.append(w)

all_words = nltk.FreqDist(all_words)


word_features = list(all_words.keys())[:5000]

# %%
# create featuresets
def find_features(t):
    features = {}
    for w in word_features:
        features[w] = (w in t)

    return features

# %%
featuresets_train = []
featuresets_test = []

for i in range(len(cleaned_x_train)):
    featuresets_train.append((find_features(cleaned_x_train[i]), y_train[i]))

for i in range(len(cleaned_x_test)):
    featuresets_test.append((find_features(cleaned_x_test[i]), y_test[i]))

# %%
# Model and test
classifier = nltk.NaiveBayesClassifier.train(featuresets_train)
print("Original Naive Bayes Algo accuracy percent:", (nltk.classify.accuracy(classifier, featuresets_test))*100)
classifier.show_most_informative_features(15)
# Out:
# Original Naive Bayes Algo accuracy percent: 84.416
# Most Informative Features
#                     2/10 = True              neg : pos    =     75.0 : 1.0
#                     *1/2 = True              neg : pos    =     57.0 : 1.0
#                     3/10 = True              neg : pos    =     43.6 : 1.0
#                     boll = True              neg : pos    =     39.7 : 1.0
#                      uwe = True              neg : pos    =     37.7 : 1.0
#                     1/10 = True              neg : pos    =     22.7 : 1.0
#                    dreck = True              neg : pos    =     20.4 : 1.0
#                 intermin = True              neg : pos    =     19.7 : 1.0
#                    wayan = True              neg : pos    =     19.7 : 1.0
#                terrible. = True              neg : pos    =     19.0 : 1.0
#                 semblanc = True              neg : pos    =     16.2 : 1.0
#                  unwatch = True              neg : pos    =     16.1 : 1.0
#                  stinker = True              neg : pos    =     15.9 : 1.0
#                    razzi = True              neg : pos    =     15.7 : 1.0
#                   flimsi = True              neg : pos    =     14.7 : 1.0

# %%
with open("NaiveBayesClassifier_imdb.pickle", "wb") as f:
    pickle.dump(classifier, f)

# %%
with open("NaiveBayesClassifier_imdb.pickle", "rb") as f:
    classifier = pickle.load(f)

# %%
transcripts_x = []
transcripts_y = []

file_list = os.listdir('data')
for file in file_list:
    with open('data/' + file, 'r') as f:
        transcripts = json.load(f)
        transcripts_x.extend(transcripts['text'].values())
        transcripts_y.extend(transcripts['sentiment'].values())

# %%
#build a pandas df and drop all neutral rows
d = {'review': transcripts_x, 'label': transcripts_y}
df_transcripts = pd.DataFrame(data=d)

#drop all neutral rows
df_transcripts = df_transcripts[df_transcripts['label'] != 'neutral']

# %%
#replace positive and negative to pos and neg
df_transcripts['label'] = df_transcripts['label'].str.replace('positive','pos')
df_transcripts['label'] = df_transcripts['label'].str.replace('negative','neg')

# %%
df_transcripts
# Out:
#                                                 review label
# 10   Great. Thank you for taking my question. I gue...   pos
# 11   Thank you, Justin. Yeah, let me just remind yo...   pos
# 12   I'll just remind you that the units – those do...   pos
# 13   In-stock is very strong, especially as we head...   pos
# 14   And, Justin, this is Dave. Just to add on to t...   neg
# 18   But I also point out that we launched Turkey i...   pos
# 21   Sure. Let me start with Q3 and this will be co...   pos
# 23   In our fulfillment center world, we had grown ...   pos
# 25   If you look at capital leases, which is where ...   pos
# 28   Yeah, thanks for your question. This growth ra...   pos
# 33   So if you, even factoring that, and we're look...   pos
# 35   This is the quarter where that will reverse. T...   pos
# 36   On the Robotics, I don't have much to say on a...   pos
# 39   Sure. Yeah, I think we've started to show our ...   pos
# 40   We've also expanded grocery pickup and that's ...   pos
# 41   On the storefront, we're also, as you can see,...   pos
# 46   But the other comment about cost, I believe yo...   pos
# 51   Let me start with PillPack. The deal closed in...   pos
# 56   Yeah. Thanks, Jason. This is Dave. Just quickl...   neg
# 58   Yeah. And your comment on revenue versus opera...   neg
# 62   Yeah, let me talk a little bit more broadly ab...   pos
# 65   Yeah, and this is Dave. Just jumping on the Al...   pos
# 66   Second thing, I mean, making the Alexa service...   pos
# 72   Yeah. Sure. Let me start with the Amazon Prime...   pos
# 73   So we do continue to make the Prime offer bett...   pos
# 75   This is Dave. Just on the AWS pricing philosop...   neg
# 83   Thanks, Deborah, and thank you all for joining...   pos
# 84   Last quarter, for the first time, we also shar...   pos
# 85   Today, I want to talk about our strategy overa...   pos
# 86   Two, we're seeing video grow dramatically acro...   pos
# ..                                                 ...   ...
# 578  So what we're learning more and more is that, ...   pos
# 579  So that gives us – and we do it over many titl...   pos
# 580  And Eric just sort of on the financial aspect ...   neg
# 581  And that would lead to maybe my next question,...   pos
# 582  It’s either for Ted or I'll take that the sort...   pos
# 583  Yes. We've really been trying to optimize and ...   pos
# 585  It's mostly the latter Eric, so we’re not acti...   neg
# 587  The biggest one is foreign exchange in terms o...   neg
# 588  If you think of our content cost as pretty big...   neg
# 589  So following up on that Reed and maybe for any...   neg
# 590  Eric, you're using the word loss and I think y...   pos
# 591  Reed took the immediate one that I was going t...   pos
# 592  And that's really going to drive the free cash...   pos
# 593  But we expect material improvements in 2020. W...   pos
# 594  And then in terms of peak leverage, I think wh...   pos
# 595  One of the key themes in the shareholder lette...   pos
# 597  Well, I’ll tell you going back just a few year...   pos
# 598  So when we invest in original show, we find th...   pos
# 599  We have a variety of models in which we used t...   pos
# 600  In some cases they produce that for us in the ...   pos
# 601  In terms of backfilling things that are coming...   pos
# 602  So and with that we have much steadier access ...   pos
# 604  We announced yesterday our co-production on Sh...   pos
# 605  And we'll do a lot more of that. Bodyguard is ...   pos
# 607  What’s super amazing about that today has been...   pos
# 610  Well, we've been thrilled just recently and we...   pos
# 614  So in just all these different ways, which we ...   pos
# 618  Yes, I think about it, if you've got five to 1...   neg
# 619  Of course, we diversified in a streaming, so w...   pos
# 621  So with that, let me thank everyone for partic...   pos
#
# [379 rows x 2 columns]

# %%
transcripts_x = df_transcripts['review'].tolist()
transcripts_y = df_transcripts['label'].tolist()

# %%
cleaned_transcripts_x = clean(transcripts_x)
featuresets_transcripts = []

for i in range(len(cleaned_transcripts_x)):
    featuresets_transcripts.append((find_features(cleaned_transcripts_x[i]), transcripts_y[i]))

# %%
transcripts_features = [f[0] for f in featuresets_transcripts]
transcripts_labels = [f[1] for f in featuresets_transcripts]

# %%
transcripts_features[0]
# Out:
# {'stori': False,
#  'man': False,
#  'unnatur': False,
#  'feel': False,
#  'pig': False,
#  '.': True,
#  'start': False,
#  'open': False,
#  'scene': False,
#  'terrif': False,
#  'exampl': False,
#  'absurd': False,
#  'comedi': False,
#  'formal': False,
#  'orchestra': False,
#  'audienc': False,
#  'turn': False,
#  'insan': False,
#  ',': True,
#  'violent': False,
#  'mob': False,
#  'crazi': False,
#  'chant': False,
#  "'s": True,
#  'singer': False,
#  'unfortun': False,
#  'stay': False,
#  'whole': False,
#  'time': False,
#  'gener': False,
#  'narr': False,
#  'eventu': False,
#  'make': False,
#  'put': False,
#  'even': False,
#  'era': False,
#  'cryptic': False,
#  'dialogu': False,
#  'would': False,
#  'shakespear': False,
#  'seem': False,
#  'easi': False,
#  'third': False,
#  'grader': False,
#  'technic': False,
#  'level': False,
#  'better': False,
#  'might': False,
#  'think': False,
#  'good': False,
#  'cinematographi': False,
#  'futur': False,
#  'great': True,
#  'vilmo': False,
#  'zsigmond': False,
#  'star': False,
#  'salli': False,
#  'kirkland': False,
#  'freder': False,
#  'forrest': False,
#  'seen': False,
#  'briefli': False,
#  'airport': False,
#  "'77": False,
#  'brand': False,
#  'new': False,
#  'luxuri': False,
#  '747': False,
#  'plane': False,
#  'load': False,
#  'valuabl': False,
#  'paint': False,
#  '&': False,
#  'belong': False,
#  'rich': False,
#  'businessman': False,
#  'philip': False,
#  'steven': False,
#  '(': False,
#  'jame': False,
#  'stewart': False,
#  ')': False,
#  'fli': False,
#  'bunch': False,
#  'vip': False,
#  'estat': False,
#  'prepar': False,
#  'public': False,
#  'museum': False,
#  'also': False,
#  'board': False,
#  'daughter': False,
#  'juli': False,
#  'kathleen': False,
#  'quinlan': False,
#  'son': False,
#  'jetlin': False,
#  'take': True,
#  'plan': False,
#  'mid-air': False,
#  'hi-jack': False,
#  'co-pilot': False,
#  'chamber': False,
#  'robert': False,
#  'foxworth': False,
#  'two': False,
#  'accomplic': False,
#  'banker': False,
#  'mont': False,
#  'markham': False,
#  'wilson': False,
#  'michael': False,
#  'pataki': False,
#  'knock': False,
#  'passeng': False,
#  'crew': False,
#  'sleep': False,
#  'ga': False,
#  'steal': False,
#  'cargo': False,
#  'land': False,
#  'disus': False,
#  'strip': False,
#  'isol': False,
#  'island': False,
#  'descent': False,
#  'almost': False,
#  'hit': False,
#  'oil': False,
#  'rig': False,
#  'ocean': False,
#  'lose': False,
#  'control': False,
#  'send': False,
#  'crash': False,
#  'sea': False,
#  'sink': False,
#  'bottom': False,
#  'right': False,
#  'bang': False,
#  'middl': False,
#  'bermuda': False,
#  'triangl': False,
#  'air': False,
#  'short': False,
#  'suppli': False,
#  'water': False,
#  'leak': False,
#  'flown': False,
#  '200': False,
#  'mile': False,
#  'cours': False,
#  'problem': False,
#  'mount': False,
#  'survivor': False,
#  'await': False,
#  'help': False,
#  'fast': False,
#  'run': False,
#  '...': False,
#  '<': False,
#  'br': False,
#  '/': False,
#  '>': False,
#  'known': False,
#  'slightli': False,
#  'differ': False,
#  'tile': False,
#  '1977': False,
#  'second': False,
#  'sequel': False,
#  'smash-hit': False,
#  'disast': False,
#  'thriller': False,
#  '1970': False,
#  'direct': False,
#  'jerri': False,
#  'jameson': False,
#  'like': False,
#  'predecessor': False,
#  'ca': False,
#  "n't": False,
#  'say': False,
#  'sort': False,
#  'forgotten': False,
#  'classic': False,
#  'entertain': False,
#  'although': False,
#  'necessarili': False,
#  'reason': False,
#  'three': False,
#  'film': False,
#  'far': False,
#  'actual': False,
#  'one': True,
#  'best': False,
#  'favourit': False,
#  'plot': False,
#  'nice': False,
#  'see': False,
#  '?': True,
#  'mayb': True,
#  'maker': False,
#  'tri': False,
#  'cross': False,
#  'origin': False,
#  'anoth': False,
#  'popular': False,
#  'flick': False,
#  'period': False,
#  'poseidon': False,
#  'adventur': False,
#  '1972': False,
#  'submerg': False,
#  'end': False,
#  'stark': False,
#  'dilemma': False,
#  'face': False,
#  'trap': False,
#  'insid': False,
#  'either': False,
#  'suffoc': False,
#  'drown': False,
#  'flood': False,
#  'door': False,
#  'decent': False,
#  'idea': False,
#  'could': True,
#  'made': False,
#  'littl': True,
#  'bad': False,
#  'unsympathet': False,
#  'charact': False,
#  'dull': False,
#  'letharg': False,
#  'set-piec': False,
#  'real': False,
#  'lack': False,
#  'danger': False,
#  'suspens': False,
#  'tension': False,
#  'mean': False,
#  'miss': False,
#  'opportun': False,
#  'rather': False,
#  'sluggish': False,
#  'keep': False,
#  '108': False,
#  'odd': False,
#  'minut': False,
#  'much': False,
#  'happen': False,
#  'urgenc': False,
#  'thought': False,
#  'navi': False,
#  'becom': False,
#  'involv': False,
#  'thing': False,
#  'pick': False,
#  'shot': False,
#  'huge': False,
#  'ship': False,
#  'helicopt': False,
#  'someth': False,
#  'georg': False,
#  'kennedi': False,
#  'jinx': False,
#  'airlin': False,
#  'worker': False,
#  'joe': False,
#  'patroni': False,
#  'back': False,
#  'get': False,
#  'coupl': True,
#  'bare': False,
#  'anyth': False,
#  'prefer': False,
#  'look': False,
#  'worri': False,
#  'background.': False,
#  'home': False,
#  'video': False,
#  'theatric': False,
#  'version': False,
#  'us': False,
#  'tv': False,
#  'add': False,
#  'extra': False,
#  'hour': False,
#  'footag': False,
#  'includ': False,
#  'credit': False,
#  'sequenc': False,
#  'mani': False,
#  'flashback': False,
#  'flesh': False,
#  'longer': False,
#  'rescu': False,
#  'discoveri': False,
#  'dead': False,
#  'bodi': False,
#  'navig': False,
#  'sure': False,
#  'sit': False,
#  'near': False,
#  'cut': False,
#  'expect': False,
#  'date': False,
#  'badli': False,
#  'horribl': False,
#  'fashion': False,
#  'interior': False,
#  'design': False,
#  'choic': False,
#  'toy': False,
#  'model': False,
#  'effect': False,
#  'along': False,
#  'pride': False,
#  'place': False,
#  'razzi': False,
#  'award': False,
#  'hall': False,
#  'shame': False,
#  'lot': False,
#  'wors': False,
#  'reckon': False,
#  'harsh': False,
#  'action': False,
#  'pace': False,
#  'slow': False,
#  'excit': False,
#  'pretti': False,
#  'properly.': False,
#  'product': False,
#  'valu': False,
#  'alright': False,
#  'noth': False,
#  'spectacular': False,
#  'act': False,
#  'oscar': False,
#  'winner': False,
#  'jack': False,
#  'lemmon': False,
#  'said': False,
#  'sinc': False,
#  'mistak': False,
#  'old': False,
#  'frail': False,
#  'lee': False,
#  'grant': False,
#  'drunk': False,
#  'sir': False,
#  'christoph': False,
#  'given': False,
#  'plenti': False,
#  'familiar': False,
#  'too.': False,
#  'orient': False,
#  'behind': False,
#  'bit': True,
#  'silli': False,
#  'bland': False,
#  'though': False,
#  'sunken': False,
#  'bore': False,
#  'follow': False,
#  'concord': False,
#  "'79": False,
#  '1979': False,
#  'finger': False,
#  'first': False,
#  ':': False,
#  'charisma': False,
#  'part': False,
#  'lead': False,
#  'actress': False,
#  'inevit': False,
#  'translat': False,
#  'chemistri': False,
#  'share': False,
#  'screen': False,
#  'romant': False,
#  'came': False,
#  'across': False,
#  'mere': False,
#  'actor': False,
#  'play': False,
#  'well': False,
#  'director': False,
#  'miscalcul': False,
#  'need': False,
#  'know.': False,
#  'screenplay': False,
#  'exactli': False,
#  'chef': False,
#  'love': False,
#  'enamor': False,
#  'culinari': False,
#  'skill': False,
#  'restaur': False,
#  'ultim': False,
#  'youth': False,
#  'exploit': False,
#  'anybodi': False,
#  'els': False,
#  'never': False,
#  'convinc': False,
#  'princess.': False,
#  'disappoint': False,
#  'movi': False,
#  'forget': False,
#  'nomin': False,
#  'judg': False,
#  'sorri': False,
#  'everyon': False,
#  'know': True,
#  'suppos': False,
#  '``': False,
#  'art': False,
#  "''": False,
#  'wow': False,
#  'hand': False,
#  'gun': False,
#  'peopl': False,
#  'blow': False,
#  'brain': False,
#  'watch': False,
#  'photograph': False,
#  'excel': False,
#  'pain': False,
#  'absenc': False,
#  'sound': False,
#  'track': False,
#  'brutal': False,
#  'loooonnnnng': False,
#  'long': False,
#  'talk': False,
#  'especi': False,
#  'complain': False,
#  'realli': False,
#  'hard': False,
#  'perform': False,
#  'dark': False,
#  'sombr': False,
#  'uninspir': False,
#  'stuff': False,
#  'maureen': False,
#  'stapleton': False,
#  'red': False,
#  'dress': False,
#  'danc': False,
#  'otherwis': False,
#  'ripoff': False,
#  'bergman': False,
#  "'m": False,
#  'fan': False,
#  'f': False,
#  'anyon': False,
#  'enjoy': False,
#  '1': False,
#  '1/2': False,
#  'lie': False,
#  'parent': False,
#  'took': False,
#  'theater': False,
#  'walk': False,
#  'recent': False,
#  'live': False,
#  'rest': False,
#  'life': False,
#  'without': False,
#  'pretenti': False,
#  'ponder': False,
#  'piec': False,
#  '70': False,
#  'wine': False,
#  'chees': False,
#  'tripe': False,
#  'woodi': False,
#  'allen': False,
#  'favorit': False,
#  'worst': False,
#  'crap': False,
#  'career': False,
#  'unmistak': False,
#  'style': False,
#  'ingmar': False,
#  'berman': False,
#  'give': False,
#  'angular': False,
#  'mute': False,
#  'insight': False,
#  'famili': False,
#  'wrought': False,
#  'psycholog': False,
#  'damag': False,
#  'caus': False,
#  'divorc': False,
#  'estrang': False,
#  'non-lov': False,
#  'halitosi': False,
#  'whatev': False,
#  'intent': False,
#  'comic': False,
#  'relief': False,
#  'music': False,
#  'drench': False,
#  'shadowi': False,
#  'patho': False,
#  'defin': False,
#  'expressionist': False,
#  'natur': False,
#  'use': False,
#  'improvis': False,
#  'method': False,
#  'illicit': False,
#  'pronounc': False,
#  'depth': False,
#  'truth': False,
#  'beyond': False,
#  'simpli': False,
#  'connect': False,
#  'sympathi': False,
#  'instead': False,
#  'felt': False,
#  'contempt': False,
#  'parad': False,
#  'shuffl': False,
#  'whine': False,
#  'nicotin': False,
#  'stain': False,
#  'martyr': False,
#  'perpetu': False,
#  'quest': False,
#  'ident': False,
#  'amid': False,
#  'backdrop': False,
#  'cosmopolitan': False,
#  'affluenc': False,
#  'bake': False,
#  'brie': False,
#  'intelligentsia': False,
#  'loom': False,
#  'fart': False,
#  'room': False,
#  'speak': False,
#  'affect': False,
#  'platitud': False,
#  'elev': False,
#  'languag': False,
#  'cigarett': False,
#  'lost': False,
#  'struggl': False,
#  'desper': False,
#  'find': False,
#  'understand': False,
#  'goe': False,
#  'point': False,
#  'want': False,
#  'slap': False,
#  'resolut': False,
#  'intermin': False,
#  'introspect': False,
#  'babbl': False,
#  'drama': False,
#  'taken': False,
#  'extrem': False,
#  'abil': False,
#  'chose': False,
#  'immers': False,
#  'left': False,
#  'found': False,
#  'self': False,
#  'indulg': False,
#  'spiritu': False,
#  'drain': False,
#  'go': False,
#  'insist': False,
#  'promot': False,
#  'messag': False,
#  'prozac': False,
#  'prose': False,
#  'distort': False,
#  'techniqu': False,
#  'jettison': False,
#  'past': False,
#  'relev': False,
#  'highli': False,
#  'recommend': False,
#  "'re": False,
#  'happi': False,
#  'remind': False,
#  'death': False,
#  'let': False,
#  'pretend': False,
#  'appear': False,
#  'critic': False,
#  'unpalat': False,
#  'unbear': False,
#  'wooden': False,
#  'imit': False,
#  'kid': False,
#  'mostli': False,
#  'support': False,
#  'pretens': False,
#  'accus': False,
#  'contrari': False,
#  'notwithstand': False,
#  'applaud': False,
#  'contemporan': False,
#  'brian': False,
#  'depalma': False,
#  'excori': False,
#  'rip': False,
#  'hitchcock': False,
#  'suspense/horror': False,
#  'robin': False,
#  'wood': False,
#  'view': False,
#  'strang': False,
#  'form': False,
#  'cultur': False,
#  'snobberi': False,
#  'agre': False,
#  'attempt': False,
#  'york': False,
#  'intellectu': False,
#  'less': False,
#  '10': False,
#  'year': True,
#  'swedish': False,
#  '-': False,
#  'susan': False,
#  'sontag': False,
#  'brother': False,
#  'carl': False,
#  'sweden': False,
#  '!': False,
#  'result': False,
#  'wild': False,
#  'refer': False,
#  'dicken': False,
#  "'": False,
#  'curios': False,
#  'shop': False,
#  'heart': False,
#  'stone': False,
#  'laugh': False,
#  'loud': False,
#  'nell': False,
#  'chock': False,
#  'full': False,
#  'solemnli': False,
#  'inton': False,
#  'howler': False,
#  'afraid': False,
#  'anger': False,
#  'distanc': False,
#  'directori': False,
#  'quotat': False,
#  'polit': False,
#  'term': False,
#  'close': False,
#  'parodi': False,
#  'incred': False,
#  'self-involv': False,
#  'brilliant': False,
#  'talent': False,
#  'strangul': False,
#  'read': False,
#  'poem': False,
#  'day': False,
#  'yorker': False,
#  'oh': False,
#  'rework': False,
#  'care': False,
#  'howev': False,
#  'quit': False,
#  'hilari': False,
#  'dialog': False,
#  'funni': False,
#  'earlier': False,
#  'line': False,
#  'straight': False,
#  'cast': False,
#  'poor': False,
#  'mari': False,
#  'beth': False,
#  'hurt': False,
#  'copi': False,
#  'thespian': False,
#  'tic': False,
#  'neurot': False,
#  'habit': False,
#  'embarrass': False,
#  'surrog': False,
#  'kenneth': False,
#  'branagh': False,
#  'celebr': False,
#  'basic': False,
#  'dysfunct': False,
#  'quietli': False,
#  'domin': False,
#  'mother': False,
#  'lift': False,
#  'winter': False,
#  'light': False,
#  'melodrama': False,
#  'trick': False,
#  'existenti': False,
#  'angst': False,
#  'come': False,
#  'shopworn': False,
#  'visual/aur': False,
#  'deafen': False,
#  'scratch': False,
#  'pencil': False,
#  'paper': False,
#  'tower': False,
#  'surf': False,
#  'dwarf': False,
#  'beach': False,
#  'etc': False,
#  'etc.': False,
#  'later': False,
#  'seriou': False,
#  "'ll": False,
#  'rare': False,
#  'funnier': False,
#  'blame': False,
#  'timid': False,
#  'writer': False,
#  'clueless': False,
#  'paid': False,
#  'angi': False,
#  'charli': False,
#  'denis': False,
#  'rosanna': False,
#  'jon': False,
#  'enough': False,
#  'veil': False,
#  'cowardic': False,
#  'hung': False,
#  'got': False,
#  'r': False,
#  'rate': False,
#  'anyway': False,
#  'ubiquit': False,
#  'bubbl': False,
#  'bath': False,
#  '70-year-old': False,
#  'woman': False,
#  'harmon': False,
#  'sheen': False,
#  'sleepwalk': False,
#  'potenti': False,
#  'hot': False,
#  'relationship': False,
#  'beauti': False,
#  'sexi': False,
#  'world': False,
#  'whoopi': False,
#  'goldberg': False,
#  'judi': False,
#  'tenuta': False,
#  'predict': False,
#  'surpris': False,
#  'five': False,
#  'wast': False,
#  'viewer': False,
#  'mediocr': False,
#  'bag': False,
#  'hammer': False,
#  'bitchi': False,
#  'demeanor': False,
#  'law': False,
#  'order': False,
#  'carri': False,
#  'fail': False,
#  'unscath': False,
#  'anti-comedi': False,
#  'posit': False,
#  'mess': False,
#  'marriag': False,
#  'hope': False,
#  'effort': False,
#  'produc': False,
#  'way': False,
#  'weak': False,
#  'outdat': False,
#  'countri': False,
#  'walker': False,
#  'subject': False,
#  'believ': False,
#  '2007': False,
#  'set': False,
#  'dc': False,
#  'rang': False,
#  'true': False,
#  'applaus': False,
#  'low': False,
#  'quick': False,
#  'q': False,
#  'either.': False,
#  'schrader': False,
#  'ahead': False,
#  'finish': False,
#  'jump': False,
#  'next': True,
#  'figur': False,
#  'guess': True,
#  'carter': False,
#  'privat': False,
#  'boyfriend': False,
#  'artist': False,
#  'male': False,
#  'bondag': False,
#  'tortur': False,
#  'pictur': False,
#  'iraq': False,
#  'prison': False,
#  'creat': False,
#  'subcultur': False,
#  'car': False,
#  'work': False,
#  'sens': False,
#  'really.': False,
#  'harrelson': False,
#  'flawlessli': False,
#  'may': False,
#  'twenti': False,
#  'ago': False,
#  'recogn': False,
#  'lauren': False,
#  'lili': False,
#  'kristin': False,
#  'boring.': False,
#  'unless': False,
#  'giant': False,
#  'pant': False,
#  'paul': False,
#  'utterli': False,
#  'comatos': False,
#  'process': False,
#  'ordinarili': False,
#  'properli': False,
#  'homosexu': False,
#  'd.c.': False,
#  'social': False,
#  'companion': False,
#  'wive': False,
#  'washington': False,
#  'elit': False,
#  'dimension': False,
#  'magazin': False,
#  'bounc': False,
#  'around': False,
#  'front': False,
#  'camera': False,
#  'popsicl': False,
#  'stick': False,
#  'southern': False,
#  'accent': False,
#  'rack': False,
#  'decrescendo': False,
#  'begin': False,
#  'everi': False,
#  'deliv': False,
#  'heat': False,
#  'humid': False,
#  'south': False,
#  'still': False,
#  'ounc': False,
#  'energi': False,
#  'monoton': False,
#  'moritz': False,
#  'bleibtreau': False,
#  'kind': True,
#  'mid': False,
#  'east': False,
#  'clumsi': False,
#  'written': False,
#  'incap': False,
#  'roll': False,
#  'spite': False,
#  'fact': False,
#  'german': False,
#  'sever': False,
#  'italian': False,
#  'someon': False,
#  'ya': False,
#  'toler': False,
#  'moment': False,
#  'tomlin': False,
#  'bacal': False,
#  'scott': False,
#  'thoma': False,
#  'manag': False,
#  'digniti': False,
#  'tact': False,
#  'ufortun': False,
#  'ever': False,
#  'redeem': False,
#  'endless': False,
#  'seri': False,
#  'flaw': False,
#  'worth': False,
#  'call': False,
#  'noteworthi': False,
#  'event': False,
#  'togeth': False,
#  '5': False,
#  '%': False,
#  'total': False,
#  'everyth': False,
#  '_everything_': False,
#  'fill': False,
#  'disturb': False,
#  'troubl': False,
#  'gritti': False,
#  '60': False,
#  'hazy/dark': False,
#  'liter': False,
#  'storylin': False,
#  'rosario': False,
#  'dawson': False,
#  'complet': False,
#  'nake': False,
#  'nc-17': False,
#  'saw.': False,
#  'throw': False,
#  'away': False,
#  'nap': False,
#  'probabl': True,
#  'interest': True,
#  'dream': False,
#  'discuss': False,
#  'hint': False,
#  'corrupt': False,
#  'murder': False,
#  'power': False,
#  'relat': True,
#  'topic': False,
#  'sometim': False,
#  'realist': False,
#  'nevertheless.': False,
#  'develop': False,
#  'tea': False,
#  'drink': False,
#  'ceremoni': False,
#  'visual': False,
#  'stun': False,
#  'eas': False,
#  'eye': False,
#  'strain': False,
#  'dinner': False,
#  'bed': False,
#  'shock': False,
#  'overexcit': False,
#  'sitcom': False,
#  'style.': False,
#  'fight': False,
#  'inadequaci': False,
#  'job': False,
#  'bearabl': False,
#  'watchabl': False,
#  'show': False,
#  'escort': False,
#  'investig': False,
#  'circl': False,
#  'men': False,
#  'wives.': False,
#  'thrill': False,
#  'engag': False,
#  'wrong': False,
#  'excruciatingli': False,
#  '40': False,
#  'serious': False,
#  'condens': False,
#  'ten': False,
#  'is.': False,
#  'aggrav': False,
#  'boredom': False,
#  'argument': False,
#  'plain': False,
#  'devoid': False,
#  'emot': False,
#  'stiff': False,
#  'upper': False,
#  'lip': False,
#  'higher': False,
#  'class': False,
#  'sad': False,
#  'despit': False,
#  'strong': False,
#  'must': False,
#  'harrison': False,
#  'save': False,
#  'bottom.': False,
#  ...}

# %%
transcripts_labels[0]
# Out:
# 'pos'

# %%
predicted_labels = classifier.classify_many(transcripts_features)

# %%
print('acc: ' + str(nltk.classify.accuracy(classifier, featuresets_transcripts)*100))
# Out:
# acc: 80.73878627968337

# %%
from nltk.metrics import ConfusionMatrix
print(ConfusionMatrix(transcripts_labels, predicted_labels))
# Out:
#     |   n   p |
#     |   e   o |
#     |   g   s |
# ----+---------+
# neg |  <8> 54 |
# pos |  19<298>|
# ----+---------+
# (row = reference; col = test)
